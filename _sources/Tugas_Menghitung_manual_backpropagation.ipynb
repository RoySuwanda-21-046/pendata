# %% [markdown]
# # **Tugas Menghitung Manual Backpropagation**
#  Nama : Roy Suwanda
#
#  NIM : 210411100046

# %% [markdown]
# https://github.com/RoySuwanda-21-046/data/blob/40f061c3266679b0e3768989d442245364321fd4/21-046_Roy%20Suwanda_Perhitungan%20Manual%20Backpropagation.xlsx
